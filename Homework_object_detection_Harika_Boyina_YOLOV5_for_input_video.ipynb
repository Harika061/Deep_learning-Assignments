# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.10.12 torch-2.1.0+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.4/107.7 GB disk)

# %%
pip install -U Ultralytics

# %%
pip install opencv-python

# %%
import torch

# %%
# !unzip -q ../train_data1.zip -d ../

# %%
# !python train.py --img 640 --batch 2 --epochs 100 --data custom_data_labeled.yaml --weights yolov5s.pt --cache
# Out:
# 2024-02-29 03:41:14.542294: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-29 03:41:14.542364: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-29 03:41:14.544537: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../IMG_0.MOV
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../IMG_0.MOV, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.10.12 torch-2.1.0+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/337) /content/IMG_0.MOV: 640x384 1 Person, 1 Traffic light, 258.7ms
# video 1/1 (2/337) /content/IMG_0.MOV: 640x384 1 Person, 1 Traffic light, 254.8ms
# video 1/1 (3/337) /content/IMG_0.MOV: 640x384 1 Person, 1 Traffic light, 254.6ms
# video 1/1 (4/337) /content/IMG_0.MOV: 640x384 1 Person, 1 Traffic light, 229.2ms
# ...
